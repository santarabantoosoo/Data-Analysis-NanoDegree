# %%
# imports and load data
import pandas as pd 
df = pd.read_csv('store_data.csv')

# %matplotlib inline

# %%
# explore data
df.describe()
df.info()
df.hist()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
# week      200 non-null object
# storeA    200 non-null int64
# storeB    200 non-null int64
# storeC    200 non-null int64
# storeD    200 non-null int64
# storeE    200 non-null int64
# dtypes: int64(5), object(1)
# memory usage: 9.5+ KB
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f3ff0815748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3fee7f8d30>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f3fee7c10f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3fee7780f0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f3fee71dd30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3fee71dd68>]], dtype=object)

# %%
# sales for the last month
df.tail()
df.iloc[196:, 1:].sum().plot(kind = 'bar')

# %%
# average sales
df.iloc[:, 1:].mean().plot(kind = 'pie')

# %%
# sales for the week of March 13th, 2016
df[df['week'] == '2016-03-13'].plot(kind = 'bar')

# %%
# sales for the lastest 3-month periods
